# %%
import pandas as pd
data = pd.read_csv("data.csv")
print(data)
# Out:
#    hours  mark
# 0      1    20
# 1      2    30
# 2      3    40
# 3      4    50
# 4      5    60
# 5      6    70
# 6      7    75
# 7      8    85

# %%
import matplotlib.pyplot as plt
data.plot(x="hours" , y="mark", 
kind="scatter")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
x = data[["hours"]]
y = data["mark"]
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[9]])
print("predicted marks:", prediction)
# Out:
# predicted marks: [95.53571429]
# c:\Users\itzsi\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
